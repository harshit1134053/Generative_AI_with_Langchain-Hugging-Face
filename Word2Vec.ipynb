# %%
import gensim

# %%
from gensim.models import Word2Vec, KeyedVectors

# %%
import gensim.downloader as api
wv=api.load('word2vec-google-news-300')
vec_king=wv['king']   # For king word we are checking its dimension 300 in google trained model
# Out:
# [==================================================] 100.0% 1662.8/1662.8MB downloaded

# %%
vec_king
# Out:
# array([ 1.25976562e-01,  2.97851562e-02,  8.60595703e-03,  1.39648438e-01,
#        -2.56347656e-02, -3.61328125e-02,  1.11816406e-01, -1.98242188e-01,
#         5.12695312e-02,  3.63281250e-01, -2.42187500e-01, -3.02734375e-01,
#        -1.77734375e-01, -2.49023438e-02, -1.67968750e-01, -1.69921875e-01,
#         3.46679688e-02,  5.21850586e-03,  4.63867188e-02,  1.28906250e-01,
#         1.36718750e-01,  1.12792969e-01,  5.95703125e-02,  1.36718750e-01,
#         1.01074219e-01, -1.76757812e-01, -2.51953125e-01,  5.98144531e-02,
#         3.41796875e-01, -3.11279297e-02,  1.04492188e-01,  6.17675781e-02,
#         1.24511719e-01,  4.00390625e-01, -3.22265625e-01,  8.39843750e-02,
#         3.90625000e-02,  5.85937500e-03,  7.03125000e-02,  1.72851562e-01,
#         1.38671875e-01, -2.31445312e-01,  2.83203125e-01,  1.42578125e-01,
#         3.41796875e-01, -2.39257812e-02, -1.09863281e-01,  3.32031250e-02,
# ...

# %%
len(vec_king)
# Out:
# 300

# %%
vec_king.shape
# Out:
# (300,)

# %%
wv.most_similar('king')
# Out:
# [('kings', 0.7138045430183411),
#  ('queen', 0.6510956287384033),
#  ('monarch', 0.6413194537162781),
#  ('crown_prince', 0.6204219460487366),
#  ('prince', 0.6159993410110474),
#  ('sultan', 0.5864822864532471),
#  ('ruler', 0.5797566771507263),
#  ('princes', 0.5646552443504333),
#  ('Prince_Paras', 0.5432944297790527),
#  ('throne', 0.5422104597091675)]

# %%
wv.similarity("happy","party")
# Out:
# 0.14995907

# %%
wv.most_similar("party")
# Out:
# [('Party', 0.7125183939933777),
#  ('parties', 0.6745480298995972),
#  ('partys', 0.5965837240219116),
#  ('Democratic_Party', 0.5447009205818176),
#  ('LOUDON_NH_Brad_Keselowski', 0.5346890091896057),
#  ('caucus', 0.522636890411377),
#  ('pary', 0.5175394415855408),
#  ('faction', 0.5168994665145874),
#  ('mad_hatter_tea', 0.5074613690376282),
#  ('Labour_Party', 0.4938312768936157)]

# %%
vc=wv['sport']+wv['party']-wv['people']

# %%
vc
# Out:
# array([-0.48095703, -0.1619873 ,  0.20703125, -0.35058594, -0.12005615,
#        -0.28149414,  0.45532227, -0.4423828 , -0.20077515,  0.17675781,
#        -0.06542969, -0.04052734,  0.08557129, -0.01269531, -0.05145264,
#         0.11450195,  0.41271973,  0.1850586 ,  0.40081787, -0.35107422,
#         0.54785156,  0.4416504 , -0.13580322,  0.02880859,  0.13479614,
#        -0.07373047, -0.20269775,  0.54833984,  0.6555176 ,  0.08056641,
#         0.19335938, -0.11108398,  0.70214844,  0.48291016,  0.29541016,
#        -0.28411865,  0.44482422, -0.21350098,  0.4633789 , -0.12286377,
#         0.20397949, -0.47216797,  0.36376953,  0.30212402, -0.32666016,
#        -0.25146484,  0.20996094, -0.1538086 , -0.1184082 ,  0.47216797,
#        -0.09448242,  0.0378418 , -0.203125  , -0.24450684,  0.2286377 ,
#         0.12394118,  0.2758789 , -0.07647705, -0.09521484, -0.4248047 ,
#        -0.08251953, -0.08789062,  0.05541992, -0.28320312, -0.08435059,
# ...

# %%
wv.most_similar([vc])
# Out:
# [('sport', 0.6615101099014282),
#  ('party', 0.5940614938735962),
#  ('sports', 0.43173518776893616),
#  ('Party', 0.4309679865837097),
#  ('motocross_racing', 0.40312880277633667),
#  ('club', 0.399713933467865),
#  ('sporting', 0.39764004945755005),
#  ('Hashimoto_faction', 0.3961389362812042),
#  ('Tsholotsho_debacle', 0.39542943239212036),
#  ('partys', 0.39134883880615234)]

# %%
vc=wv['king']-wv['man']+wv['woman']

# %%
vc
# Out:
# array([ 4.29687500e-02, -1.78222656e-01, -1.29089355e-01,  1.15234375e-01,
#         2.68554688e-03, -1.02294922e-01,  1.95800781e-01, -1.79504395e-01,
#         1.95312500e-02,  4.09919739e-01, -3.68164062e-01, -3.96484375e-01,
#        -1.56738281e-01,  1.46484375e-03, -9.30175781e-02, -1.16455078e-01,
#        -5.51757812e-02, -1.07574463e-01,  7.91015625e-02,  1.98974609e-01,
#         2.38525391e-01,  6.34002686e-02, -2.17285156e-02,  0.00000000e+00,
#         4.72412109e-02, -2.17773438e-01, -3.44726562e-01,  6.37207031e-02,
#         3.16406250e-01, -1.97631836e-01,  8.59375000e-02, -8.11767578e-02,
#        -3.71093750e-02,  3.15551758e-01, -3.41796875e-01, -4.68750000e-02,
#         9.76562500e-02,  8.39843750e-02, -9.71679688e-02,  5.17578125e-02,
#        -5.00488281e-02, -2.20947266e-01,  2.29492188e-01,  1.26403809e-01,
#         2.49023438e-01,  2.09960938e-02, -1.09863281e-01,  5.81054688e-02,
# ...

# %%
wv.most_similar([vc])
# Out:
# [('king', 0.8449392318725586),
#  ('queen', 0.7300517559051514),
#  ('monarch', 0.645466148853302),
#  ('princess', 0.6156251430511475),
#  ('crown_prince', 0.5818676352500916),
#  ('prince', 0.5777117609977722),
#  ('kings', 0.5613664388656616),
#  ('sultan', 0.5376776456832886),
#  ('Queen_Consort', 0.5344247221946716),
#  ('queens', 0.5289887189865112)]
